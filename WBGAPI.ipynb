# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdolan/DS_Portfolio/blob/main/WBGAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # World Bank API 🗺
#
# checking out the pythonic access to the World Bank API

# %%
# !pip install wbgapi

# %%
import pandas as pd
import numpy as mp
import matplotlib.pyplot as pt
import wbgapi as wb

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2022-07-20
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
# wb.series.info()
# wb.economy.info()
wb.search('pound')
# Out:
# ...
# Country: CHI, Channel Islands
#
# CurrencyUnit: Pound sterling
# ...
# Country: EGY, Egypt, Arab Rep.
#
# CurrencyUnit: Egyptian pound
# ...
# Country: GBR, United Kingdom
#
# CurrencyUnit: Pound sterling
# ...
# Country: GIB, Gibraltar
#
# CurrencyUnit: Gibraltar pound
# ...
# Country: IMN, Isle of Man
#
# CurrencyUnit: Pound sterling
# ...
# Country: IRL, Ireland
#
# SpecialNotes: ...rate was adopted by the EU Council on January 1, 1999: 1 euro = 0.787564 Irish pound. Please note that historical data before 1999 are not actual euros and are not...
# ...
# Country: LBN, Lebanon
#
# CurrencyUnit: Lebanese pound
# ...
# Country: SDN, Sudan
#
# CurrencyUnit: Sudanese pound
# ...
# Country: SSD, South Sudan
#
# CurrencyUnit: South Sudanese Pound
# ...
# Country: SYR, Syrian Arab Republic
#
# CurrencyUnit: Syrian pound
# ...
# Series: DT.CUR.UKPS.ZS, Currency composition of PPG debt, Pound sterling (%)
#
# IndicatorName: Currency composition of PPG debt, Pound sterling (%)
# --------
# ...

# %%
wb.search('fossil fuels')
# Out:
# ...
# Series: EG.ELC.COAL.KH, Electricity production from coal sources (kWh)
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ...
# Series: EG.ELC.COAL.ZS, Electricity production from coal sources (% of total)
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ...
# Series: EG.ELC.HYRO.KH, Electricity production from hydroelectric sources (kWh)
#
# Developmentrelevance: ...from fossil fuel combustion and cement manufacturing. In combustion different fossil fuels release different amounts of carbon dioxide for the same level of energy use:...
# ...
# Series: EG.ELC.HYRO.ZS, Electricity production from hydroelectric sources (% of total)
#
# ...

# %%
wb.data.DataFrame(['NY.GDP.PCAP.CD', 'SP.POP.TOTL'], 'CAN', mrv=5) # most recent 5 years
# Out:
#                       YR2017        YR2018        YR2019        YR2020  \
# series
# NY.GDP.PCAP.CD  4.512943e+04  4.654864e+04  4.632867e+04  4.325826e+04
# SP.POP.TOTL     3.654524e+07  3.706508e+07  3.760123e+07  3.803720e+07
#
#                       YR2021
# series
# NY.GDP.PCAP.CD  5.205135e+04
# SP.POP.TOTL     3.824611e+07

# %%
for row in wb.data.fetch('SP.POP.TOTL', 'USA'): # all years
    print(row)
# Out:
# {'value': 331893745, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2021'}
# {'value': 331501080, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2020'}
# {'value': 328329953, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2019'}
# {'value': 326838199, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2018'}
# {'value': 325122128, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2017'}
# {'value': 323071755, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2016'}
# {'value': 320738994, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2015'}
# {'value': 318386329, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2014'}
# {'value': 316059947, 'series': 'SP.POP.TOTL', 'economy': 'USA', 'aggregate': False, 'time': 'YR2013'}
# ...

# %%
wb.data.DataFrame('SP.POP.TOTL', wb.region.members('AFR'), range(2010, 2020, 2))  # population for African countries, every other year
# Out:
#               YR2010       YR2012       YR2014       YR2016       YR2018
# economy
# AGO       23356247.0   25107925.0   26941773.0   28842482.0   30809787.0
# BDI        8675606.0    9245992.0    9844301.0   10488002.0   11175379.0
# BEN        9199254.0    9729254.0   10286839.0   10872072.0   11485035.0
# BFA       15605211.0   16571252.0   17586029.0   18646350.0   19751466.0
# BWA        1987106.0    2039551.0    2088619.0    2159925.0    2254067.0
# CAF        4386765.0    4436411.0    4464171.0    4537683.0    4666375.0
# CIV       20532944.0   21547188.0   22647672.0   23822726.0   25069226.0
# CMR       20341236.0   21485267.0   22681853.0   23926549.0   25216261.0
# COD       64563853.0   69020749.0   73767445.0   78789130.0   84068092.0
# COG        4273738.0    4510197.0    4736965.0    4980996.0    5244363.0
# COM         689696.0     723865.0     759390.0     795597.0     832322.0
# CPV         492644.0     505241.0     518276.0     531140.0     543764.0
# ...

# %%
# Have population estimates for Brazil been revised over time?
# Version identifiers are in the form YYYYMM. This example queries data for the April
# versions from 2010-2019

wb.data.DataFrame('SP.POP.TOTL', 'BRA', range(2000,2005), version=range(201004,202004,100), db=57)
# Out:
#               YR2000       YR2001       YR2002       YR2003       YR2004
# version
# 201004   174174447.0  176659138.0  179123364.0  181537359.0  183863524.0
# 201104   174174447.0  176659138.0  179123364.0  181537359.0  183863524.0
# 201204   174425387.0  176877135.0  179289227.0  181633074.0  183873377.0
# 201304   174425387.0  176877135.0  179289227.0  181633074.0  183873377.0
# 201404   174504898.0  176968205.0  179393768.0  181752951.0  184010283.0
# 201504   174504898.0  176968205.0  179393768.0  181752951.0  184010283.0
# 201604   175786441.0  178419396.0  181045592.0  183627339.0  186116363.0
# 201704   175786441.0  178419396.0  181045592.0  183627339.0  186116363.0
# 201804   175287587.0  177750670.0  180151021.0  182482149.0  184738458.0
# 201904   175287587.0  177750670.0  180151021.0  182482149.0  184738458.0

# %%
wb.source.concepts(db=6)
# Out:
# {'counterpart_area': {'key': 'counterpart-area', 'value': 'Counterpart-Area'},
#  'economy': {'key': 'country', 'value': 'Country'},
#  'series': {'key': 'series', 'value': 'Series'},
#  'time': {'key': 'time', 'value': 'Time'}}

# %%
wb.economy.DataFrame()
# Out:
#                             name aggregate  longitude  latitude region  \
# id
# ABW                        Aruba     False   -70.0167  12.51670    LCN
# AFE  Africa Eastern and Southern      True        NaN       NaN
# AFG                  Afghanistan     False    69.1761  34.52280    SAS
# AFW   Africa Western and Central      True        NaN       NaN
# AGO                       Angola     False    13.2420  -8.81155    SSF
# ..                           ...       ...        ...       ...    ...
# XKX                       Kosovo     False    20.9260  42.56500    ECS
# YEM                  Yemen, Rep.     False    44.2075  15.35200    MEA
# ZAF                 South Africa     False    28.1871 -25.74600    SSF
# ZMB                       Zambia     False    28.2937 -15.39820    SSF
# ZWE                     Zimbabwe     False    31.0672 -17.83120    SSF
#
#     adminregion lendingType incomeLevel capitalCity
# id
# ABW                     LNX         HIC  Oranjestad
# AFE
# ...
