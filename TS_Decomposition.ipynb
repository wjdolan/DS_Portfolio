# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdolan/DS_Portfolio/blob/main/TS_Decomposition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Decomposing Time Series Data into Trend and Seasonality

# %%
# pip install statsmodels

# %%
import pandas as pd
import numpy as np
import statsmodels
from statsmodels.tsa.seasonal import seasonal_decompose

import matplotlib.pyplot as plt
import random
from random import randrange

# %% [markdown]
# ### Additive Decompostion

# %%
series = [i+randrange(10) for i in range(1,100)]
result = seasonal_decompose(series, model='additive', freq=1)


result.plot()

# %% [markdown]
# ### Multiplicative Decomposition

# %%
seriesA = [i**2.0 for i in range(1,100)]
resultA = seasonal_decompose(seriesA, model='multiplicative', freq=1)

resultA.plot()

# %% [markdown]
# ## Airline Passengers Dataset

# %%
passengers = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv', header=0, index_col=0)

# %%
plt.rcParams['figure.figsize'] = (10,7)

# %%
passengers.plot();

# %%
passengers.head()
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121

# %%
pass_res = seasonal_decompose(passengers, model='multiplicative', freq=1)

# pass_res.plot()

pass_res.plot()
