# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdolan/DS_Portfolio/blob/main/Gensim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implement Word2Vec with Gensim

# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import bs4 as bs
import urllib.request
import re
import nltk

scrapped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Artificial_intelligence')
article = scrapped_data .read()

parsed_article = bs.BeautifulSoup(article,'lxml')

paragraphs = parsed_article.find_all('p')

article_text = ""

for p in paragraphs:
    article_text += p.text

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# convert all text to lower case
processed_article = article_text.lower()

# remove all digits and special characters
processed_article = re.sub('[^a-zA-Z]', ' ', processed_article )

# remove extra spaces
processed_article = re.sub(r'\s+', ' ', processed_article)

# Preparing the dataset
all_sentences = nltk.sent_tokenize(processed_article)

all_words = [nltk.word_tokenize(sent) for sent in all_sentences]

# Removing Stop Words
from nltk.corpus import stopwords
for i in range(len(all_words)):
    all_words[i] = [w for w in all_words[i] if w not in stopwords.words('english')]

# %%
from gensim.models import Word2Vec

word2vec = Word2Vec(all_words, min_count=2)

# %%
vocabulary = word2vec.wv.vocab
print(vocabulary)
# Out:
# {'artificial': <gensim.models.keyedvectors.Vocab object at 0x7fe0b32c3b90>, 'intelligence': <gensim.models.keyedvectors.Vocab object at 0x7fe0b36c2f50>, 'ai': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0f67b50>, 'demonstrated': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0abea90>, 'machines': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0a4a290>, 'natural': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0a63310>, 'displayed': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0a633d0>, 'including': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0a63410>, 'humans': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0abead0>, 'research': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0a63350>, 'defined': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0a63450>, 'field': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0a63490>, 'study': <gensim.models.keyedvectors.Vocab object at 0x7fe0b0a634d0>, 'intelligent': <gensim.models.keyedvectors.Vocab obj
# ...

# %%
v1 = word2vec.wv['artificial']

# %%
sim_words = word2vec.wv.most_similar('intelligence')

# %%
sim_words
# Out:
# [('ai', 0.6574810147285461),
#  ('artificial', 0.5947312116622925),
#  ('research', 0.5314823389053345),
#  ('united', 0.5184313654899597),
#  ('use', 0.5100458860397339),
#  ('learning', 0.4782777428627014),
#  ('mind', 0.46430090069770813),
#  ('used', 0.4627646505832672),
#  ('include', 0.45445573329925537),
#  ('increase', 0.44965100288391113)]
